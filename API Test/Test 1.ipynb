# %%
import urllib3
import json
from hashlib import sha256
import time

# %%
mobile="Mobile No"
key="U2FsdGVkX18vDwDor+oOIG7vSUnINtlc/pxQcNiBulCm8LT5Sza+aIISKLqImbpMnRYgsN2QACPhggLWgZEpQg=="
date="06-06-2021"
district="770"
age=18

# %%
header={"accept":"application/json","Accept-Language":"en_US","Origin":"https://selfregistration.cowin.gov.in","Referer":"https://selfregistration.cowin.gov.in","user-agent":"Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36"}

# %%
http=urllib3.PoolManager()

# %%
#apis
generate_otp="https://cdn-api.co-vin.in/api/v2/auth/generateMobileOTP"
validate_otp="https://cdn-api.co-vin.in/api/v2/auth/validateMobileOtp"
find_by_dist="https://cdn-api.co-vin.in/api/v2/appointment/sessions/findByDistrict?district_id={0}&date={1}".format(district,date)

# %%
enc_data=json.dumps({"mobile":mobile,"secret":key}).encode("utf-8")

# %%
r=http.request("POST",generate_otp,headers=header,body=enc_data)

# %%
txnId=json.loads(r.data.decode('utf-8'))["txnId"]

# %%
r.data
# Out:
# b'{"txnId":"9ac5f285-8f75-4d45-a75f-81f20ff93ab3"}'

# %%
otpsha=sha256(str(input()).encode("utf-8")).hexdigest()
# Out:
# 322709

# %%
enc_data=json.dumps({"otp":otpsha,"txnId":txnId,"secret":key}).encode("utf-8")

# %%
r=http.request("POST",validate_otp,headers=header,body=enc_data)

# %%
token=json.loads(r.data.decode('utf-8'))["token"]

# %%
header["Authorization"]="Bearer "+token

# %%
available=""
tries=1
while True:
    print('#Try: ',tries)
    r=http.request("GET",find_by_dist,headers=header)
    data=json.loads(r.data.decode())
    sessions=data["sessions"]
    #print(sessions)
    if len(sessions)>0:
        for session in sessions:
            print(session["name"],session["session_id"])
            if session["min_age_limit"]==age and session["pincode"] in pincodes and session["available_capacity_dose1"]>0:
                available=session 
                break
    if available!="":
        break
    tries=tries+1
    time.sleep(0.20)
        
#session_id=center["session_id"]
print(available["pincode"])
print(available["name"])
# Out:
# #Try:  1
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  2
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  3
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  4
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  5
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  6
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  7
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  8
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  9
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  10
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  11
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  12
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  13
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  14
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  15
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  16
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  17
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  18
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  19
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  20
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  21
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  22
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  23
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  24
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  25
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  26
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  27
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  28
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  29
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  30
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  31
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  32
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  33
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  34
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  35
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  36
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  37
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  38
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  39
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  40
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  41
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  42
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  43
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  44
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  45
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  46
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  47
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  48
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  49
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  50
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  51
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  52
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  53
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  54
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  55
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  56
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  57
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  58
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  59
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  60
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  61
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  62
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  63
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  64
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  65
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  66
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  67
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  68
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  69
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  70
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  71
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  72
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  73
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  74
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  75
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  76
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  77
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  78
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  79
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  80
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  81
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  82
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  83
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  84
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  85
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  86
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  87
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  88
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  89
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  90
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  91
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  92
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  93
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  94
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  95
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  96
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  97
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  98
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  99
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  100
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  101
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  102
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  103
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  104
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  105
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  106
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  107
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  108
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  109
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  110
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  111
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  112
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  113
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  114
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  115
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  116
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  117
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  118
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  119
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  120
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  121
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  122
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  123
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  124
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  125
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  126
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  127
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  128
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  129
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  130
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  131
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  132
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  133
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  134
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  135
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  136
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  137
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  138
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  139
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  140
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  141
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  142
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  143
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  144
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  145
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  146
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  147
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  148
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  149
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  150
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  151
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  152
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  153
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  154
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  155
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  156
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  157
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  158
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  159
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  160
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  161
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  162
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  163
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  164
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  165
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  166
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  167
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  168
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  169
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  170
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  171
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  172
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  173
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  174
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  175
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  176
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  177
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  178
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  179
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  180
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  181
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  182
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  183
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  184
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  185
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  186
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  187
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  188
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  189
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  190
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  191
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  192
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  193
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  194
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  195
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  196
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  197
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  198
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  199
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  200
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  201
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  202
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  203
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  204
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  205
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  206
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  207
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  208
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  209
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  210
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  211
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  212
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  213
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  214
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  215
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  216
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  217
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  218
# APOLLO HOSPITALS CITY CENTRE 4eecc8b5-b36c-439d-a9bd-67acb31e9c5a
# #Try:  219
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-f1fed5d655a6> in <module>
#       3 while True:
#       4     print('#Try: ',tries)
# ----> 5     r=http.request("GET",find_by_dist,headers=header)
#       6     data=json.loads(r.data.decode())
#       7     sessions=data["sessions"]
#
# /usr/lib/python3/dist-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      73
#      74         if method in self._encode_url_methods:
# ---> 75             return self.request_encode_url(
#      76                 method, url, fields=fields, headers=headers, **urlopen_kw
#      77             )
#
# /usr/lib/python3/dist-packages/urllib3/request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      95             url += "?" + urlencode(fields)
#      96
# ---> 97         return self.urlopen(method, url, **extra_kw)
#      98
#      99     def request_encode_body(
#
# /usr/lib/python3/dist-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     328             response = conn.urlopen(method, url, **kw)
#     329         else:
# --> 330             response = conn.urlopen(method, u.request_uri, **kw)
#     331
#     332         redirect_location = redirect and response.get_redirect_location()
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     829             drain_and_release_conn(response)
#     830
# --> 831             retries.sleep(response)
#     832             log.debug("Retry: %s", url)
#     833             return self.urlopen(
#
# /usr/lib/python3/dist-packages/urllib3/util/retry.py in sleep(self, response)
#     297
#     298         if self.respect_retry_after_header and response:
# --> 299             slept = self.sleep_for_retry(response)
#     300             if slept:
#     301                 return
#
# /usr/lib/python3/dist-packages/urllib3/util/retry.py in sleep_for_retry(self, response)
#     276         retry_after = self.get_retry_after(response)
#     277         if retry_after:
# --> 278             time.sleep(retry_after)
#     279             return True
#     280
#
# KeyboardInterrupt:
